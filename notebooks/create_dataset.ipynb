# %% [markdown]
# # Create Consistent Subset of PlantCLEF 2025 Dataset

# %%
import sys 
import os

project_root = os.path.abspath('..')

if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from loading.data_loader import SinglePlantDataLoader

# %%
os.chdir("/scratch/ezq9qu/images_max_side_800")
DATA_DIR = os.getcwd()


RESIZE_SIZE = 256
IMG_SIZE = 224 
BATCH_SIZE = 32
NUM_CLASSES = 7806 # As per the challenge overview
NUM_WORKERS = 4 # Use all available CPU cores for loading

# %%
data_splitter = SinglePlantDataLoader(
        data_dir=DATA_DIR,
        resize_size=RESIZE_SIZE,
        img_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        num_workers=NUM_WORKERS
    )

# Get the dataloaders
train_loader, val_loader, test_loader = data_splitter.get_dataloaders()
# Out:
# Loading data from: /sfs/weka/scratch/ezq9qu/images_max_side_800
#
# Splitting dataset
#
# Found 1408033 total images belonging to 7806 classes.

# %%
train_loader.batch_size
# Out:
# 32

# %%
pip install peft
# Out:
# Requirement already satisfied: peft in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (0.17.1)
# Requirement already satisfied: numpy>=1.17 in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from peft) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from peft) (25.0)
# Requirement already satisfied: psutil in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from peft) (7.0.0)
# Requirement already satisfied: pyyaml in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /home/ezq9qu/.local/lib/python3.11/site-packages (from peft) (2.9.1)
# Requirement already satisfied: transformers in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from peft) (4.57.0)
# Requirement already satisfied: tqdm in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from peft) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from peft) (1.10.1)
# Requirement already satisfied: safetensors in /home/ezq9qu/.local/lib/python3.11/site-packages (from peft) (0.7.0)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /home/ezq9qu/.local/lib/python3.11/site-packages (from peft) (1.1.6)
# Requirement already satisfied: filelock in /home/ezq9qu/.local/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /home/ezq9qu/.local/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ezq9qu/.local/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (0.28.1)
# Requirement already satisfied: shellingham in /home/ezq9qu/.local/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (1.5.4)
# Requirement already satisfied: typer-slim in /home/ezq9qu/.local/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (0.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ezq9qu/.local/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (4.15.0)
# Requirement already satisfied: anyio in /home/ezq9qu/.local/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.25.0->peft) (4.12.0)
# Requirement already satisfied: certifi in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.25.0->peft) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /home/ezq9qu/.local/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.25.0->peft) (1.0.9)
# Requirement already satisfied: idna in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.25.0->peft) (3.10)
# Requirement already satisfied: h11>=0.16 in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.25.0->peft) (0.16.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.5)
# Requirement already satisfied: jinja2 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/ezq9qu/.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ezq9qu/.local/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ezq9qu/.local/lib/python3.11/site-packages (from jinja2->torch>=1.13.0->peft) (3.0.3)
# Collecting huggingface_hub>=0.25.0 (from peft)
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: regex!=2019.12.17 in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from transformers->peft) (2025.9.1)
# Requirement already satisfied: requests in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from transformers->peft) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from transformers->peft) (0.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from requests->transformers->peft) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from requests->transformers->peft) (2.5.0)
# Requirement already satisfied: click>=8.0.0 in /scratch/ezq9qu/llm_course/lib/python3.11/site-packages (from typer-slim->huggingface_hub>=0.25.0->peft) (8.2.1)
# Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 11.6 MB/s  0:00:00
# Installing collected packages: huggingface_hub
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.1.6
#     Uninstalling huggingface_hub-1.1.6:
#       Successfully uninstalled huggingface_hub-1.1.6
# Successfully installed huggingface_hub-0.36.0
# Note: you may need to restart the kernel to use updated packages.
